# %%
#INSURANCE DATA SET FOR STATS ANALYSIS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns

# %%
data=pd.read_csv('insurance.csv')
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
# Out:
# (1338, 7)

# %%
data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
plt.figure(figsize =(10,8))
sns.boxplot(data=data,x = 'age')
plt.show()

# %%
sns.distplot(data['bmi'])
plt.show()

# %%
sns.boxplot(data=data,x = 'bmi')
plt.show()

# %%
data['bmi'].skew()
# Out:
# 0.2840471105987448

# %%
plt.figure(figsize= (15,8))
sns.scatterplot(data=data,x='bmi',y='age',hue='charges')
plt.show()

# %%
data['bmi'].skew()

data['bmi1']=data['bmi'].apply(np.log)
data['bmi1']
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges      bmi1
# 0   19  female  27.900         0    yes  southwest  16884.92400  3.328627
# 1   18    male  33.770         1     no  southeast   1725.55230  3.519573
# 2   28    male  33.000         3     no  southeast   4449.46200  3.496508
# 3   33    male  22.705         0     no  northwest  21984.47061  3.122585
# 4   32    male  28.880         0     no  northwest   3866.85520  3.363149

# %%
data['age'].skew()
# Out:
# 0.05567251565299186

# %%
data['bmi1'].skew()
# Out:
# -0.2566549543197403

# %%
data['charges'].skew()
# Out:
# 1.5158796580240388

# %%
sns.distplot(a = data['charges'])
plt.show()

# %%
sns.distplot(a = data['age'])
plt.show()

# %%
sns.distplot(a = data['bmi1'])
plt.show()

# %%
sns.boxplot(x= data.age, color='lightblue')

# %%
sns.boxplot(x= data.age, color='lightblue')

# %%
sns.boxplot(x= data.bmi, color='lightblue')

# %%
sns.boxplot(x= data.charges, color='lightblue')

# %%
# bmi has quite outliers and chargers has more extreme outliers

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.countplot(x=data['sex'])
plt.show()

# %%
sns.countplot(x=data['region'])
plt.show()

# %%
sns.countplot(x=data['children'])
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
import copy
data.loc[:,['sex', 'smoker', 'region']] = data.loc[:,['sex', 'smoker', 'region']].apply(LabelEncoder().fit_transform) 
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
sns.countplot(x=data['smoker'])
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data.age, data.charges,hue=data.smoker,palette= ['red','green'] ,alpha=0.6)
plt.show()

# %%
sns.scatterplot(data.age,data.charges,hue=data.smoker)
plt.show()

# %%
#h0:smoker=non smoker
#ha:smoker!=non smoker

# %%
sns.distplot(data.smoker)
plt.show()
# Out:
# C:\Users\Famin\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
data['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
x=data[data['smoker']=='yes'].charges
x
# Out:
# 0       16884.92400
# 11      27808.72510
# 14      39611.75770
# 19      36837.46700
# 23      37701.87680
#            ...
# 1313    36397.57600
# 1314    18765.87545
# 1321    28101.33305
# 1323    43896.37630
# 1337    29141.36030
# Name: charges, Length: 274, dtype: float64

# %%
y=data[data['smoker']=='no'].charges
y
# Out:
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
# 5        3756.62160
#            ...
# 1332    11411.68500
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# Name: charges, Length: 1064, dtype: float64

# %%
x.mean(),y.mean()
# Out:
# (32050.23183153285, 8434.268297856199)

# %%
x.std(),y.std()
# Out:
# (11541.547175589121, 5993.781819194933)

# %%
ttest=(32050.23183153285-8434.268297856199)/np.sqrt(((11541.547175589121**2)/274)+((5993.781819194933**2)/1064))
ttest
# Out:
# 32.75188776634185

# %%
#two sample t test
from scipy.stats import ttest_ind,ttest_rel
stats.ttest_ind(x,y)
# Out:
# Ttest_indResult(statistic=46.664921172723716, pvalue=8.271435842177219e-283)

# %%
#ha holds good
# Out:
# (32050.23183153285, 8434.268297856199)

# %%
#Does bmi of males differ significantly from that of females?

# %%
sns.scatterplot(data.age,data.charges,hue=data.sex)
plt.show()

# %%
a=data[data['sex']=='male'].bmi
a
# Out:
# 1       33.770
# 2       33.000
# 3       22.705
# 4       28.880
# 8       29.830
#          ...
# 1324    25.935
# 1325    33.535
# 1327    30.030
# 1329    38.600
# 1333    30.970
# Name: bmi, Length: 676, dtype: float64

# %%
b=data[data['sex']=='female'].bmi
b
# Out:
# 0       27.90
# 5       25.74
# 6       33.44
# 7       27.74
# 9       25.84
#         ...
# 1332    44.70
# 1334    31.92
# 1335    36.85
# 1336    25.80
# 1337    29.07
# Name: bmi, Length: 662, dtype: float64

# %%
a.mean(),b.mean()
# Out:
# (30.943128698224832, 30.377749244713023)

# %%
a.std(),b.std()
# Out:
# (6.140434615792248, 6.046023085745338)

# %%
stats.ttest_ind(a,b)
# Out:
# Ttest_indResult(statistic=1.696752635752224, pvalue=0.08997637178984932)

# %%
#therefore  gender has no effect on bmi

# %%
ttest=(30.943128-30.37774)/np.sqrt(((6.14043**2)/676)+((6.04602**2)/662))
ttest
# Out:
# 1.6970546579755783

# %%
#Is the proportion of smokers significantly different in different genders?

# %%
df=pd.crosstab(data['sex'],data['smoker'])
df
# Out:
# smoker   no  yes
# sex
# female  547  115
# male    517  159

# %%
from scipy.stats import chi2_contingency

# %%
stats.chi2_contingency(df)
# Out:
# (7.39291081459996,
#  0.006548143503580696,
#  1,
#  array([[526.43348281, 135.56651719],
#         [537.56651719, 138.43348281]]))

# %%
#ha hold good

# %%
#Is the distribution of bmi across women with no children, one child and two children, the same?
h0:no effect on bmi
ha:effect on bmi

# %%
from scipy.stats import f_oneway
g1=A['salary'][A['department']=='Engineering']

# %%
female_df = copy.deepcopy(data[data['sex'] == 'female'])

# %%
zero=female_df[female_df['children']==0].bmi
one=female_df[female_df['children']==1].bmi
two=female_df[female_df['children']==2].bmi

# %%
stats.f_oneway(zero,one,two)
# Out:
# F_onewayResult(statistic=0.3344720147757968, pvalue=0.7158579926754841)
